# %%
from matplotlib import pyplot as plt

# %%
X = [1,2,3,4,5,6,7,8]
Y = [34,56,78,12,34,23,14,4]
plt.plot(X,Y)# line graph
plt.title("My first plot")
plt.xlabel("X values")
plt.ylabel("Y values")
#title,labels,legend,color,width,markers.
# Out:
# Text(0, 0.5, 'Y values')

# %%
#There are 5 subjects Psycology,Nano technology,Medicine,Onchology,Anthropology two students have applied two do masters in any of these 5 fields with lineplot show in which field they can excel
#The Cutoff for each subject is 70
sub = ["Psycology","Nano technology","Medicine","Onchology","Anthropology"]
Student1=[67,45,73,71,57]
Student2=[43,67,68,53,85]
Cutoff=[70,70,70,70,70]
#student1
#plt.plottype(X,Y,label,color,marker,linewidth,linestyle)
plt.scatter(sub,Student1,label="Student1",color ='k',marker='P')
#student2
plt.scatter(sub,Student2,label="Student2",color ='b',marker='H')
#Cutoff
plt.plot(sub,Cutoff,label="Cutoff",color ='r',linestyle=":",linewidth=4)
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.legend()

# %%
#An India v/s Australia match is on live ,India has given 298 as target for Australia,The runs for every 5 overs is given as follows 25,51,84,131,160,189,220,250,267,297
#Australia hava completed 25 overs,Runs for 5 overs are 15,41,94,110,151
#Plot overs v/s runs for both the countries and india has blue line and australia has yellow line
#With required labels and legend ,The market for india is flag and australia is plus
#Take overs from a range function create runs as arrays ,linewidth=2
import numpy as np
from matplotlib import pyplot as p
import numpy as np
india=np.array([25,51,84,131,160,189,220,250,267,297])
Aas=np.array([15,41,94,110,151])
overs_india=np.arange(5,51,5)
overs_aus=np.arange(5,26,5)
plt.plot(overs_india,india,label='India',color='b',marker=">",linewidth=2)
plt.plot(overs_aus,aus,label='Aus',color='y',marker="P",linewidth=2)
plt.title("IND v/s AUS")
plt.xlabel('Overs')
plt.ylabel("runs")
plt.legend()
plt.grid()
