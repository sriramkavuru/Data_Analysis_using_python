# %%
import pandas as pd
import seaborn as sns

# %%
d1 = pd.read_csv("/content/tn.csv")
d1
# Out:
#        stn_code sampling_date       state location  \
# 0          38.0    27-01-1987  Tamil Nadu   Madras
# 1          38.0    13-04-1987  Tamil Nadu   Madras
# 2          38.0    05-01-1987  Tamil Nadu   Madras
# 3          38.0    06-01-1987  Tamil Nadu   Madras
# 4          38.0    07-01-1987  Tamil Nadu   Madras
# ...         ...           ...         ...      ...
# 18424      71.0    22-06-2015  Tamil Nadu  Chennai
# 18425      71.0    25-06-2015  Tamil Nadu  Chennai
# 18426      71.0    29-06-2015  Tamil Nadu  Chennai
# 18427      71.0    09-07-2015  Tamil Nadu  Chennai
# 18428      71.0    13-07-2015  Tamil Nadu  Chennai
#
#                                         agency             type   so2   no2  \
# 0           Tamil Nadu Pollution Control Board       Industrial   0.5   0.3
# 1           Tamil Nadu Pollution Control Board       Industrial  12.9   1.3
# 2           Tamil Nadu Pollution Control Board       Industrial  38.8   0.9
# ...

# %%
pl=sns.lineplot(x='so2',y='no2',data=d1)

# %%
pl=sns.lineplot(y='state',x='location',color='b',data=d1)

# %%
pl=sns.lineplot(y='spm',x='type',hue='type',data=d1)

# %%
pl=sns.lineplot(x='spm',y='location',data=d1)
